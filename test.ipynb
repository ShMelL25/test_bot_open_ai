# %%
import os
from openai import OpenAI

client = OpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("OPENAI_API_KEY", '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'),
)


assistant = client.beta.assistants.create(
    name="Леночка",
    instructions="Добрый  день, я представляю группу компаний БИТУМ ЭКСПРЕС В ВАШ ДОМ. Мы производим высоскокачественный битум. Скажите вам это интересно?",
    model="gpt-4"
)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[1], line 10
#       2 from openai import OpenAI
#       4 client = OpenAI(
#       5     # This is the default and can be omitted
#       6     api_key=os.environ.get("OPENAI_API_KEY", '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'),
#       7 )
# ---> 10 assistant = client.beta.assistants.create(
#      11     name="Леночка",
#      12     instructions="Добрый  день, я представляю группу компаний БИТУМ ЭКСПРЕС В ВАШ ДОМ. Мы производим высоскокачественный битум. Скажите вам это интересно?",
#      13     model="gpt-4"
#      14 )
#
# File c:\Users\egor\Documents\open_ai_venv\Lib\site-packages\openai\resources\beta\assistants\assistants.py:112, in Assistants.create(self, model, description, file_ids, instructions, metadata, name, tools, extra_headers, extra_query, extra_body, timeout)
#      74 """
# ...

# %%
thread = client.beta.threads.create()
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 thread = client.beta.threads.create()
#
# File c:\Users\egor\Documents\open_ai_venv\Lib\site-packages\openai\resources\beta\threads\threads.py:114, in Threads.create(self, messages, metadata, extra_headers, extra_query, extra_body, timeout)
#      93 """
#      94 Create a thread.
#      95
#    (...)
#     111   timeout: Override the client-level default timeout for this request, in seconds
#     112 """
#     113 extra_headers = {"OpenAI-Beta": "assistants=v1", **(extra_headers or {})}
# --> 114 return self._post(
#     115     "/threads",
#     116     body=maybe_transform(
#     117         {
#     118             "messages": messages,
#     119             "metadata": metadata,
#     120         },
#     121         thread_create_params.ThreadCreateParams,
#     122     ),
# ...

# %%
message = client.beta.threads.messages.create(
    thread_id=thread.id,
    role="user",
    content="Добрый день!",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 message = client.beta.threads.messages.create(
# ----> 2     thread_id=thread.id,
#       3     role="user",
#       4     content="Добрый день!",
#       5 )
#
# NameError: name 'thread' is not defined

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            'thread_id'=thread.id,
            "role": "user",
            "content": "Добрый день!",
        }
    ],
    model="gpt-4",)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 chat_completion = client.chat.completions.create(
#       2     messages=[
#       3         {
#       4             "role": "user",
#       5             "content": "Добрый день!",
#       6         }
#       7     ],
#       8     model="gpt-4",)
#
# File c:\Users\egor\Documents\open_ai_venv\Lib\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# ...

# %%
import json

# %%
with open('core/telegram/config_open_ai.json') as f:
    templates = json.load(f)
